# %%
#name ="obi is a boy"

# %%
#name

# %%
#var1 =("favour")

# %%
#(var1)

# %%
#x = y = z = "chicken"

# %%
#(x), (y), (z)

# %%
#x, y, z = "apple", "mango", "chicken"

# %%
#(x), (y), (z)

# %%
#var2 ="ada is a girl"

# %%
#(var2[2])

# %%
#(var2[0:7])

# %%
#items =["apple", "mango", "chicken"]

# %%
#(items[2])

# %%
#(items[1])

# %%
#name ="favour enwereji"

# %%
#age ="26"

# %%
#print(name)
# Out:
# favour enwereji

# %%
#print(age)
# Out:
# 26

# %%
#("hello, world")
# Out:
# 'hello, world'

# %%
#(f"my name is {name} and i am {age} years old")
# Out:
# 'my name is favour enwereji and i am 26 years old'

# %%
#print(bool("hello, world"))
# Out:
# True

# %%
#(bool(""))
# Out:
# False

# %%
#(bool(0))
# Out:
# False

# %%
#(bool("0"))
# Out:
# True

# %%
#(bool(123))
# Out:
# True

# %%
#print(5 == 7)
# Out:
# False

# %%
#(5 != 7)
# Out:
# True

# %%
#a = 25

# %%
#a += 25

# %%
#a = 25+2

# %%
#(a)
# Out:
# 27

# %%
a = 25-2

# %%
(a)
# Out:
# 23

# %%
a = 25 * 4

# %%
(a)
# Out:
# 100

# %%
#a = 25 % 2

# %%
#(a)
# Out:
# 1

# %%
#a = 25 / 2

# %%
#(a)
# Out:
# 12.5

# %%
#a = 25 // 2

# %%
#(a)
# Out:
# 12

# %%
#a = 25 ** 2

# %%
#(a)
# Out:
# 625

# %%
#a&=25

# %%
#a = 25 & 2

# %%
#(a)
# Out:
# 0

# %%
#a|=25

# %%
#a = 25 | 2

# %%
#(a)
# Out:
# 27

# %%
#x = 3

# %%
#(x<5 or x>10)
# Out:
# False

# %%
#(not(x<3 and x>10))
# Out:
# True

# %%
#x = 200
#y = 200

# %%
#(x is y)
# Out:
# True

# %%
#(x >= y)
# Out:
# True

# %%
#girls=("amanda", "chimuanya","ngozi")

# %%
#("amanda" in girls)
# Out:
# True

# %%
#("obi" in girls)
# Out:
# False

# %%
items =["shark", "whale", "dolphin", "sardine"]

# %%
(type(items))
# Out:
# list

# %%
(len(items))
# Out:
# 4

# %%
item1 =["fish", "meat","muton","eggs"]
item2 =[1, 3, 5, 7, 9]
item3 =[True, False, False]

# %%
Item5 =["fish", 43, True, 57, "male"]

# %%
(Item5)
# Out:
# ['fish', 43, True, 57, 'male']

# %%
thislist = list(("fish", "meat","muton","eggs"))

# %%
(thislist)
# Out:
# ['fish', 'meat', 'muton', 'eggs']
