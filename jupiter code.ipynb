# %%
name ="obi is a boy"

# %%
name
# Out:
# 'obi is a boy'

# %%
var1 =("favour")

# %%
(var1)
# Out:
# 'favour'

# %%
x = y = z = "chicken"

# %%
(x), (y), (z)
# Out:
# ('chicken', 'chicken', 'chicken')

# %%
x, y, z = "apple", "mango", "chicken"

# %%
(x), (y), (z)
# Out:
# ('apple', 'mango', 'chicken')

# %%
var2 ="ada is a girl"

# %%
(var2[2])
# Out:
# 'a'

# %%
(var2[0:7])
# Out:
# 'ada is '

# %%
items =["apple", "mango", "chicken"]

# %%
(items[2])
# Out:
# 'chicken'

# %%
(items[1])
# Out:
# 'mango'
